# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
from scipy.spatial import Voronoi, voronoi_plot_2d
import skimage.util as ski
import shapely
import shapely.geometry
import shapely.plotting
import shapely.ops
import cv2
# %matplotlib widget
im = plt.imread('ExampleMap.png')
#https://stackoverflow.com/questions/12201577/how-can-i-convert-an-rgb-image-into-grayscale-in-python

img = cv2.imread("ExampleMap.png")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img.copy(),cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray, 125, 255, 0)

contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

copy_img = img.copy()
cv2.drawContours(copy_img,contours,-1,(0,0,255),2)

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])
grey = rgb2gray(im)

coordinates = np.argwhere(grey < 0.99)

# Gives coordinates of the outline of the map. WAYYYYY too many points. Will have to shrink it down to something more managable.
a = coordinates[:,0]
b = coordinates[:,1]
c = a
d = b
halves = 4
for i in range(halves):
    c = np.delete(c, np.arange(0, c.size, 3))
    d = np.delete(d, np.arange(0, d.size, 3))   

titles = ['original','contours']
imgs = [img, copy_img]

fig = plt.figure(1, figsize = [5,5], dpi=90)

ax = fig.add_subplot(111)
ax.set_box_aspect(1)
current_shapes = []

for contour in contours:
    current_shape = []
    for coord in contour:
        current_shape.append(tuple(coord[0]))
    print(current_shape)
    current_shapes.append(current_shape)


for i in range(1,len(current_shapes)):
    shapely.plotting.plot_polygon(shapely.geometry.Polygon(current_shapes[i]), facecolor='lightblue', edgecolor='red')
    

#shortened_coords = np.stack((c,d)).T
#result = tuple(map(tuple, shortened_coords))
#print(len(shortened_coords))
#print(shortened_coords)
#print(coordinates)
#print(c)
#print(d)
#bob = Voronoi(shortened_coords)
#olygon_1 = geometry.Polygon(np.squeeze(points_np_array))
#shapely_shortened_coords = shapely.MultiPoint(result)

bob =  shapely.ops.voronoi_diagram(current_shapes[0])
#print(len(bob))



print(len(c))
#print(coordinates)
#ax = plt.axes()
#print(coordinates[:,0])
#coordinate_blocks = coordinates[:,0].reshape(4,4)
#print(coordinate_blocks)

#ax.set_box_aspect(1)
#ax.scatter(d, c)
#ax.set_aspect('equal')
#plt.xticks([])  # Replace with the specific tick positions you want
#plt.yticks()  # Replace with the specific tick positions you want
#plt.show()
#print(shortened_coords)
#print(shapely_shortened_coords)
#print(bob)

#ax.plot(bob)
#shapely.plotting.plot_polygon(bob)

# https://www.ri.cmu.edu/pub_files/pu   b1/choset_howie_1996_1/choset_howie_1996_1.pdf
# Out:
# KeyboardInterrupt

# %% [markdown]
# for i in range (2):
#     plt.subplot(1,2,i+1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.title(titles[i])
#     plt.imshow(imgs[i])
# plt.show()

# %% [markdown]
# from scipy import ndimage as ndi
#
# #Msmall = ski.view_as_blocks(coordinates, (2,len(coordinates)))
# #print(Msmall)
#
# m = 4#int(len(coordinates[:,0]) // 8) # Needs to be integer devisible
# a = coordinates[:,0]
# b = a.reshape(-1, m).mean(axis=1)
#
# c = coordinates[:,1]
# d = c.reshape(-1, m).mean(axis=1)
# #print(len())
# #shrunk_coordinates = np.array(b,d)

# %% [markdown]
# import matplotlib.pyplot as plt
# import numpy as np
# import scipy as sp
# from scipy.spatial import Voronoi, voronoi_plot_2d
# import skimage.util as ski
# import shapely
# import shapely.ops
# import shapely.plotting
# %matplotlib widget
# im = plt.imread('ExampleMap.png')
# #https://stackoverflow.com/questions/12201577/how-can-i-convert-an-rgb-image-into-grayscale-in-python
# def rgb2gray(rgb):
#     return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])
# grey = rgb2gray(im)
#
# coordinates = np.argwhere(grey < 0.99)
# # Gives coordinates of the outline of the map. WAYYYYY too many points. Will have to shrink it down to something more managable.
# a = coordinates[:,0]
# b = coordinates[:,1]
# c = a
# d = b
# halves = 4
# for i in range(halves):
#     c = np.delete(c, np.arange(0, c.size, 3))
#     d = np.delete(d, np.arange(0, d.size, 3))
#
# shortened_coords = np.stack((c,d)).T
# result = tuple(map(tuple, shortened_coords))
# #print(len(shortened_coords))
# #print(shortened_coords)
# #print(coordinates)
# #print(c)
# #print(d)
# #bob = Voronoi(shortened_coords)
# #olygon_1 = geometry.Polygon(np.squeeze(points_np_array))
# shapely_shortened_coords = shapely.MultiPoint(result)
#
# bob =  shapely.ops.voronoi_diagram(shapely_shortened_coords)
# #print(len(bob))
#
#
#
# print(len(c))
# #print(coordinates)
# ax = plt.axes()
# #print(coordinates[:,0])
# #coordinate_blocks = coordinates[:,0].reshape(4,4)
# #print(coordinate_blocks)
#
# ax.set_box_aspect(1)
# ax.scatter(d, c)
# ax.set_aspect('equal')
# plt.xticks([])  # Replace with the specific tick positions you want
# plt.yticks()  # Replace with the specific tick positions you want
# plt.show()
# print(shortened_coords)
# print(shapely_shortened_coords)
# print(bob)
#
# #ax.plot(bob)
# shapely.plotting.plot_polygon(bob)
#
#
# # Sweepline algorithm???
#
# https://www.ri.cmu.edu/pub_files/pub1/thrun_sebastian_1996_1/thrun_sebastian_1996_1.pdf
#
# Simulate the enviroment digitially with sonar in each direction
